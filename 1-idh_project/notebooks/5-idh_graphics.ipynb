# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
base = pd.read_csv('../data/economicdata2020v3.csv', sep=',')

# %%
base.drop(['countries'], axis=1, inplace=True)
indexies = pd.DataFrame(list(base.columns))

# %%
indexies.drop([19])
# Out:
#                                                     0
# 0                               judicial independence
# 1                                    impartial courts
# 2                       protection of property rights
# 3   military interference in rule of law and politics
# 4                       integrity of the legal system
# 5                      legal enforcement of contracts
# 6                               reliability of police
# 7                      legal system & property rights
# 8                           non-tariff trade barriers
# 9         compliance costs of importing and exporting
# 10                          regulatory trade barriers
# 11                                 financial openness
# 12     controls of the movement of capital and people
# 13                   freedom to trade internationally
# 14                                  regulatory burden
# 15                    impartial public administration
# ...

# %%
# Gerando gráfico de dispersão de índice por índice para análise. 
for i in range(0, 18):
    plt.figure(figsize = (8, 8))
    sns.set_theme(style = 'darkgrid')
    x = 'human development index'
    y = base.columns[i]
    hue = 'categories'
    sns.scatterplot(data=base, x=x, y=y, hue=hue)
    #plt.savefig(y+'png')
